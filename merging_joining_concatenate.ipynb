# %% [markdown]
# <a href="https://colab.research.google.com/github/mradi004/data_science/blob/main/merging_joining_concatenate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
courses=pd.read_csv('/content/courses.csv')
ipl=pd.read_csv('/content/deliveries (1).csv')
matches=pd.read_csv('/content/matches.csv')
nov=pd.read_csv('/content/reg-month1.csv')
dec=pd.read_csv('/content/reg-month2.csv')
students=pd.read_csv('/content/students.csv')

# %%
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
regs=pd.concat([nov,dec],ignore_index=True)

# %%
multi=pd.concat([nov,dec],keys=['nov','dec'])

# %%
multi.loc[('dec', 0)]
# Out:
# student_id    3
# course_id     5
# Name: (dec, 0), dtype: int64

# %%
pd.concat([nov,dec],axis=1)
# Out:
#     student_id  course_id  student_id  course_id
# 0         23.0        1.0           3          5
# 1         15.0        5.0          16          7
# 2         18.0        6.0          12         10
# 3         23.0        4.0          12          1
# 4         16.0        9.0          14          9
# 5         18.0        1.0           7          7
# 6          1.0        1.0           7          2
# 7          7.0        8.0          16          3
# 8         22.0        3.0          17         10
# 9         15.0        1.0          11          8
# 10        19.0        4.0          14          6
# 11         1.0        6.0          12          5
# 12         7.0       10.0          12          7
# 13        11.0        7.0          18          8
# 14        13.0        3.0           1         10
# 15        24.0        4.0           1          9
# 16        21.0        1.0           2          5
# 17        16.0        5.0           7          6
# 18        23.0        3.0          22          5
# 19        17.0        7.0          22          6
# 20        23.0        6.0          23          9
# 21        25.0        1.0          23          5
# 22        19.0        2.0          14          4
# 23        25.0       10.0          14          1
# 24         3.0        3.0          11         10
# 25         NaN        NaN          42          9
# 26         NaN        NaN          50          8
# 27         NaN        NaN          38          1

# %%
#joins

# %%
students.merge(regs,how='inner',on='student_id')
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23          1
# 1            1       Kailash Harjo       23          6
# 2            1       Kailash Harjo       23         10
# 3            1       Kailash Harjo       23          9
# 4            2         Esha Butala        1          5
# 5            3      Parveen Bhalla        3          3
# 6            3      Parveen Bhalla        3          5
# 7            7        Tarun Thaker        9          8
# 8            7        Tarun Thaker        9         10
# 9            7        Tarun Thaker        9          7
# 10           7        Tarun Thaker        9          2
# 11           7        Tarun Thaker        9          6
# 12          11  David Mukhopadhyay       20          7
# 13          11  David Mukhopadhyay       20          8
# 14          11  David Mukhopadhyay       20         10
# 15          12          Radha Dutt       19         10
# 16          12          Radha Dutt       19          1
# 17          12          Radha Dutt       19          5
# 18          12          Radha Dutt       19          7
# 19          13      Munni Varghese       24          3
# 20          14    Pranab Natarajan       22          9
# 21          14    Pranab Natarajan       22          6
# 22          14    Pranab Natarajan       22          4
# 23          14    Pranab Natarajan       22          1
# 24          15           Preet Sha       16          5
# 25          15           Preet Sha       16          1
# 26          16        Elias Dodiya       25          9
# 27          16        Elias Dodiya       25          5
# 28          16        Elias Dodiya       25          7
# 29          16        Elias Dodiya       25          3
# 30          17        Yasmin Palan        7          7
# 31          17        Yasmin Palan        7         10
# 32          18     Fardeen Mahabir       13          6
# 33          18     Fardeen Mahabir       13          1
# 34          18     Fardeen Mahabir       13          8
# 35          19        Qabeel Raman       12          4
# 36          19        Qabeel Raman       12          2
# 37          21          Seema Kota       15          1
# 38          22          Yash Sethi       21          3
# 39          22          Yash Sethi       21          5
# 40          22          Yash Sethi       21          6
# 41          23      Chhavi Lachman       18          1
# 42          23      Chhavi Lachman       18          4
# 43          23      Chhavi Lachman       18          3
# 44          23      Chhavi Lachman       18          6
# 45          23      Chhavi Lachman       18          9
# 46          23      Chhavi Lachman       18          5
# 47          24        Radhika Suri       17          4
# 48          25     Shashank D’Alia        2          1
# 49          25     Shashank D’Alia        2         10

# %%
courses.merge(regs,how='left',on='course_id')
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499        23.0
# 1           1            python   2499        18.0
# 2           1            python   2499         1.0
# 3           1            python   2499        15.0
# 4           1            python   2499        21.0
# 5           1            python   2499        25.0
# 6           1            python   2499        12.0
# 7           1            python   2499        14.0
# 8           1            python   2499        38.0
# 9           2               sql   3499        19.0
# 10          2               sql   3499         7.0
# 11          3     data analysis   4999        22.0
# 12          3     data analysis   4999        13.0
# 13          3     data analysis   4999        23.0
# 14          3     data analysis   4999         3.0
# 15          3     data analysis   4999        16.0
# 16          4  machine learning   9999        23.0
# 17          4  machine learning   9999        19.0
# 18          4  machine learning   9999        24.0
# 19          4  machine learning   9999        14.0
# 20          5           tableau   2499        15.0
# 21          5           tableau   2499        16.0
# 22          5           tableau   2499         3.0
# 23          5           tableau   2499        12.0
# 24          5           tableau   2499         2.0
# 25          5           tableau   2499        22.0
# 26          5           tableau   2499        23.0
# 27          6          power bi   1899        18.0
# 28          6          power bi   1899         1.0
# 29          6          power bi   1899        23.0
# 30          6          power bi   1899        14.0
# 31          6          power bi   1899         7.0
# 32          6          power bi   1899        22.0
# 33          7          ms sxcel   1599        11.0
# 34          7          ms sxcel   1599        17.0
# 35          7          ms sxcel   1599        16.0
# 36          7          ms sxcel   1599         7.0
# 37          7          ms sxcel   1599        12.0
# 38          8            pandas   1099         7.0
# 39          8            pandas   1099        11.0
# 40          8            pandas   1099        18.0
# 41          8            pandas   1099        50.0
# 42          9            plotly    699        16.0
# 43          9            plotly    699        14.0
# 44          9            plotly    699         1.0
# 45          9            plotly    699        23.0
# 46          9            plotly    699        42.0
# 47         10           pyspark   2499         7.0
# 48         10           pyspark   2499        25.0
# 49         10           pyspark   2499        12.0
# 50         10           pyspark   2499        17.0
# 51         10           pyspark   2499         1.0
# 52         10           pyspark   2499        11.0
# 53         11             Numpy    699         NaN
# 54         12               C++   1299         NaN

# %%
#right join
tempp_df=pd.DataFrame({
    'student_id':[26,27,24,27],
    'name':['aadi','bhutki','shiva','pari'],
    'partner':[26,27,24,17]
})

# %%
students=pd.concat((students,tempp_df),ignore_index=True)

# %%
students.merge(regs,how='outer',on='student_id').tail(10)
# Out:
#     student_id             name  partner  course_id
# 54          24     Radhika Suri     17.0        4.0
# 55          24            shiva     24.0        4.0
# 56          25  Shashank D’Alia      2.0        1.0
# 57          25  Shashank D’Alia      2.0       10.0
# 58          26             aadi     26.0        NaN
# 59          27           bhutki     27.0        NaN
# 60          27             pari     17.0        NaN
# 61          38              NaN      NaN        1.0
# 62          42              NaN      NaN        9.0
# 63          50              NaN      NaN        8.0

# %%
#practice questions

# %%
#1
#total revenue generated by any company
total=regs.merge(courses,on='course_id')['price'].sum()

# %%
total
# Out:
# np.int64(154247)

# %%
#find month by month revenue
temp=pd.concat([nov,dec],keys=['nov','dec']).reset_index()

# %%
temp.merge(courses,on='course_id').groupby('level_0')['price'].sum()
# Out:
# level_0
# dec    65072
# nov    89175
# Name: price, dtype: int64

# %%
regs.merge(students,on='student_id').merge(courses,on='course_id')[['name','course_name','price']].set_index('name')
# Out:
#                          course_name  price
# name
# Chhavi Lachman                python   2499
# Preet Sha                    tableau   2499
# Fardeen Mahabir             power bi   1899
# Chhavi Lachman      machine learning   9999
# Elias Dodiya                  plotly    699
# Fardeen Mahabir               python   2499
# Kailash Harjo                 python   2499
# Tarun Thaker                  pandas   1099
# Yash Sethi             data analysis   4999
# Preet Sha                     python   2499
# Qabeel Raman        machine learning   9999
# Kailash Harjo               power bi   1899
# Tarun Thaker                 pyspark   2499
# David Mukhopadhyay          ms sxcel   1599
# Munni Varghese         data analysis   4999
# Radhika Suri        machine learning   9999
# shiva               machine learning   9999
# Seema Kota                    python   2499
# Elias Dodiya                 tableau   2499
# Chhavi Lachman         data analysis   4999
# Yasmin Palan                ms sxcel   1599
# Chhavi Lachman              power bi   1899
# Shashank D’Alia               python   2499
# Qabeel Raman                     sql   3499
# Shashank D’Alia              pyspark   2499
# Parveen Bhalla         data analysis   4999
# Parveen Bhalla               tableau   2499
# Elias Dodiya                ms sxcel   1599
# Radha Dutt                   pyspark   2499
# Radha Dutt                    python   2499
# Pranab Natarajan              plotly    699
# Tarun Thaker                ms sxcel   1599
# Tarun Thaker                     sql   3499
# Elias Dodiya           data analysis   4999
# Yasmin Palan                 pyspark   2499
# David Mukhopadhyay            pandas   1099
# Pranab Natarajan            power bi   1899
# Radha Dutt                   tableau   2499
# Radha Dutt                  ms sxcel   1599
# Fardeen Mahabir               pandas   1099
# Kailash Harjo                pyspark   2499
# Kailash Harjo                 plotly    699
# Esha Butala                  tableau   2499
# Tarun Thaker                power bi   1899
# Yash Sethi                   tableau   2499
# Yash Sethi                  power bi   1899
# Chhavi Lachman                plotly    699
# Chhavi Lachman               tableau   2499
# Pranab Natarajan    machine learning   9999
# Pranab Natarajan              python   2499
# David Mukhopadhyay           pyspark   2499

# %%
regs.merge(courses,on='course_id').groupby('course_name')['price'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='course_name'>

# %%
common=np.intersect1d(dec['student_id'],dec['student_id'])

# %%
students[students['student_id'].isin(common)]
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 6            7        Tarun Thaker        9
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 13          14    Pranab Natarajan       22
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# 20          21          Seema Kota       15
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18
# 23          24        Radhika Suri       17
# 24          25     Shashank D’Alia        2
# 25          26                aadi       26
# 26          27              bhutki       27
# 27          24               shiva       24
# 28          27                pari       17

# %%
regs
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# 34          11          8
# 35          14          6
# 36          12          5
# 37          12          7
# 38          18          8
# 39           1         10
# 40           1          9
# 41           2          5
# 42           7          6
# 43          22          5
# 44          22          6
# 45          23          9
# 46          23          5
# 47          14          4
# 48          14          1
# 49          11         10
# 50          42          9
# 51          50          8
# 52          38          1

# %%
#find course in which no student get enrolled
com2=np.setdiff1d(courses['course_id'],regs['course_id'])

# %%
courses[courses['course_id'].isin(com2)]
# Out:
#     course_id course_name  price
# 10         11       Numpy    699
# 11         12         C++   1299

# %%
#print student name -> partner name
students.merge(students,how='inner',left_on='partner',right_on='student_id')[['name_x','name_y']]
# Out:
#                 name_x              name_y
# 0        Kailash Harjo      Chhavi Lachman
# 1          Esha Butala       Kailash Harjo
# 2       Parveen Bhalla      Parveen Bhalla
# 3          Marlo Dugal    Pranab Natarajan
# 4          Kusum Bahri  Lakshmi Contractor
# 5   Lakshmi Contractor      Aayushman Sant
# 6         Tarun Thaker   Nitika Chatterjee
# 7       Radheshyam Dey         Kusum Bahri
# 8    Nitika Chatterjee         Marlo Dugal
# 9       Aayushman Sant      Radheshyam Dey
# 10  David Mukhopadhyay       Hanuman Hegde
# 11          Radha Dutt        Qabeel Raman
# 12      Munni Varghese        Radhika Suri
# 13      Munni Varghese               shiva
# 14    Pranab Natarajan          Yash Sethi
# 15           Preet Sha        Elias Dodiya
# 16        Elias Dodiya     Shashank D’Alia
# 17        Yasmin Palan        Tarun Thaker
# 18     Fardeen Mahabir      Munni Varghese
# 19        Qabeel Raman          Radha Dutt
# 20       Hanuman Hegde  David Mukhopadhyay
# 21          Seema Kota           Preet Sha
# 22          Yash Sethi          Seema Kota
# 23      Chhavi Lachman     Fardeen Mahabir
# 24        Radhika Suri        Yasmin Palan
# 25     Shashank D’Alia         Esha Butala
# 26                aadi                aadi
# 27              bhutki              bhutki
# 28              bhutki                pari
# 29               shiva        Radhika Suri
# 30               shiva               shiva
# 31                pari        Yasmin Palan

# %%
#top 3 student who did the most number of enrollments
regs.merge(students,on='student_id').groupby(['student_id','name'])['name'].count().sort_values(ascending=False).head(3)
# Out:
# student_id  name
# 23          Chhavi Lachman    6
# 7           Tarun Thaker      5
# 1           Kailash Harjo     4
# Name: name, dtype: int64

# %%
regs.merge(students,on='student_id').merge(courses,on='course_id').groupby(['student_id','name'])['price'].sum().sort_values(ascending=False).head(3)
# Out:
# student_id  name
# 23          Chhavi Lachman      22594
# 14          Pranab Natarajan    15096
# 19          Qabeel Raman        13498
# Name: price, dtype: int64

# %%
ipl
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# 3       Royal Challengers Bangalore     1     4      DA Warner       S Dhawan
# 4       Royal Challengers Bangalore     1     5      DA Warner       S Dhawan
# ...                             ...   ...   ...            ...            ...
# 150455          Sunrisers Hyderabad    20     2    Sachin Baby      CJ Jordan
# 150456          Sunrisers Hyderabad    20     3    Sachin Baby      CJ Jordan
# 150457          Sunrisers Hyderabad    20     4  Iqbal Abdulla    Sachin Baby
# 150458          Sunrisers Hyderabad    20     5    Sachin Baby  Iqbal Abdulla
# 150459          Sunrisers Hyderabad    20     6  Iqbal Abdulla    Sachin Baby
#
#           bowler  is_super_over  ...  bye_runs  legbye_runs  noball_runs  \
# 0       TS Mills              0  ...         0            0            0
# 1       TS Mills              0  ...         0            0            0
# 2       TS Mills              0  ...         0            0            0
# 3       TS Mills              0  ...         0            0            0
# 4       TS Mills              0  ...         0            0            0
# ...          ...            ...  ...       ...          ...          ...
# 150455   B Kumar              0  ...         0            0            0
# 150456   B Kumar              0  ...         0            0            0
# 150457   B Kumar              0  ...         0            1            0
# 150458   B Kumar              0  ...         0            0            0
# 150459   B Kumar              0  ...         0            0            0
#
#         penalty_runs  batsman_runs  extra_runs  total_runs  player_dismissed  \
# 0                  0             0           0           0               NaN
# 1                  0             0           0           0               NaN
# 2                  0             4           0           4               NaN
# 3                  0             0           0           0               NaN
# 4                  0             0           2           2               NaN
# ...              ...           ...         ...         ...               ...
# 150455             0             2           0           2               NaN
# 150456             0             0           0           0         CJ Jordan
# 150457             0             0           1           1               NaN
# 150458             0             1           0           1               NaN
# 150459             0             4           0           4               NaN
#
#        dismissal_kind  fielder
# 0                 NaN      NaN
# 1                 NaN      NaN
# 2                 NaN      NaN
# 3                 NaN      NaN
# 4                 NaN      NaN
# ...               ...      ...
# 150455            NaN      NaN
# 150456        run out  NV Ojha
# 150457            NaN      NaN
# 150458            NaN      NaN
# 150459            NaN      NaN
#
# [150460 rows x 21 columns]

# %%
#ipl problems
#find top 3 studies with highest sixes/match ratio
#find orange cap holder of all the seasons

# %%
temp=ipl.merge(matches,left_on='match_id',right_on='id')

# %%
six=temp[temp['batsman_runs']==6]

# %%
six
# Out:
#         match_id  inning                 batting_team  \
# 10             1       1          Sunrisers Hyderabad
# 47             1       1          Sunrisers Hyderabad
# 75             1       1          Sunrisers Hyderabad
# 89             1       1          Sunrisers Hyderabad
# 91             1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150395       636       2  Royal Challengers Bangalore
# 150413       636       2  Royal Challengers Bangalore
# 150428       636       2  Royal Challengers Bangalore
# 150440       636       2  Royal Challengers Bangalore
# 150453       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball       batsman     non_striker  \
# 10      Royal Challengers Bangalore     2     4     DA Warner        S Dhawan
# 47      Royal Challengers Bangalore     8     4  MC Henriques        S Dhawan
# 75      Royal Challengers Bangalore    13     2  Yuvraj Singh    MC Henriques
# 89      Royal Challengers Bangalore    15     3  Yuvraj Singh    MC Henriques
# 91      Royal Challengers Bangalore    15     5  MC Henriques    Yuvraj Singh
# ...                             ...   ...   ...           ...             ...
# 150395          Sunrisers Hyderabad    10     2       V Kohli        CH Gayle
# 150413          Sunrisers Hyderabad    13     2       V Kohli  AB de Villiers
# 150428          Sunrisers Hyderabad    15     5     SR Watson        KL Rahul
# 150440          Sunrisers Hyderabad    17     5     STR Binny     Sachin Baby
# 150453          Sunrisers Hyderabad    19     6   Sachin Baby       CJ Jordan
#
#                    bowler  is_super_over  ...  result  dl_applied  \
# 10            A Choudhary              0  ...  normal           0
# 47                TM Head              0  ...  normal           0
# 75            A Choudhary              0  ...  normal           0
# 89              S Aravind              0  ...  normal           0
# 91              S Aravind              0  ...  normal           0
# ...                   ...            ...  ...     ...         ...
# 150395  Mustafizur Rahman              0  ...  normal           0
# 150413            BB Sran              0  ...  normal           0
# 150428       MC Henriques              0  ...  normal           0
# 150440  Mustafizur Rahman              0  ...  normal           0
# 150453  Mustafizur Rahman              0  ...  normal           0
#
#                      winner  win_by_runs  win_by_wickets  player_of_match  \
# 10      Sunrisers Hyderabad           35               0     Yuvraj Singh
# 47      Sunrisers Hyderabad           35               0     Yuvraj Singh
# 75      Sunrisers Hyderabad           35               0     Yuvraj Singh
# 89      Sunrisers Hyderabad           35               0     Yuvraj Singh
# 91      Sunrisers Hyderabad           35               0     Yuvraj Singh
# ...                     ...          ...             ...              ...
# 150395  Sunrisers Hyderabad            8               0      BCJ Cutting
# 150413  Sunrisers Hyderabad            8               0      BCJ Cutting
# 150428  Sunrisers Hyderabad            8               0      BCJ Cutting
# 150440  Sunrisers Hyderabad            8               0      BCJ Cutting
# 150453  Sunrisers Hyderabad            8               0      BCJ Cutting
#
#                                             venue          umpire1  \
# 10      Rajiv Gandhi International Stadium, Uppal      AY Dandekar
# 47      Rajiv Gandhi International Stadium, Uppal      AY Dandekar
# 75      Rajiv Gandhi International Stadium, Uppal      AY Dandekar
# 89      Rajiv Gandhi International Stadium, Uppal      AY Dandekar
# 91      Rajiv Gandhi International Stadium, Uppal      AY Dandekar
# ...                                           ...              ...
# 150395                      M Chinnaswamy Stadium  HDPK Dharmasena
# 150413                      M Chinnaswamy Stadium  HDPK Dharmasena
# 150428                      M Chinnaswamy Stadium  HDPK Dharmasena
# 150440                      M Chinnaswamy Stadium  HDPK Dharmasena
# 150453                      M Chinnaswamy Stadium  HDPK Dharmasena
#
#              umpire2 umpire3
# 10          NJ Llong     NaN
# 47          NJ Llong     NaN
# 75          NJ Llong     NaN
# 89          NJ Llong     NaN
# 91          NJ Llong     NaN
# ...              ...     ...
# 150395  BNJ Oxenford     NaN
# 150413  BNJ Oxenford     NaN
# 150428  BNJ Oxenford     NaN
# 150440  BNJ Oxenford     NaN
# 150453  BNJ Oxenford     NaN
#
# [6523 rows x 39 columns]

# %%
six.groupby('venue')['venue'].count()
# Out:
# venue
# Barabati Stadium                                         68
# Brabourne Stadium                                       114
# Buffalo Park                                             27
# De Beers Diamond Oval                                    34
# Dr DY Patil Sports Academy                              173
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     129
# Dubai International Cricket Stadium                      58
# Eden Gardens                                            594
# Feroz Shah Kotla                                        636
# Green Park                                               36
# Himachal Pradesh Cricket Association Stadium            108
# Holkar Cricket Stadium                                   88
# JSCA International Stadium Complex                       76
# Kingsmead                                               130
# M Chinnaswamy Stadium                                   873
# MA Chidambaram Stadium, Chepauk                         507
# Maharashtra Cricket Association Stadium                 169
# Nehru Stadium                                            39
# New Wanderers Stadium                                    64
# Newlands                                                 63
# OUTsurance Oval                                           8
# Punjab Cricket Association IS Bindra Stadium, Mohali     87
# Punjab Cricket Association Stadium, Mohali              307
# Rajiv Gandhi International Stadium, Uppal               492
# Sardar Patel Stadium, Motera                            130
# Saurashtra Cricket Association Stadium                  104
# Sawai Mansingh Stadium                                  243
# Shaheed Veer Narayan Singh International Stadium         44
# Sharjah Cricket Stadium                                  76
# Sheikh Zayed Stadium                                     40
# St George's Park                                         62
# Subrata Roy Sahara Stadium                              141
# SuperSport Park                                         120
# Vidarbha Cricket Association Stadium, Jamtha             26
# Wankhede Stadium                                        657
# Name: venue, dtype: int64

# %%
#find orange cap holder
temp.groupby(['season','batsman'])['batsman_runs'].sum().reset_index().sort_values(by='batsman_runs',ascending=False).drop_duplicates(subset='season',keep='first').sort_values('season')
# Out:
#       season       batsman  batsman_runs
# 115     2008      SE Marsh           616
# 229     2009     ML Hayden           572
# 446     2010  SR Tendulkar           618
# 502     2011      CH Gayle           608
# 684     2012      CH Gayle           733
# 910     2013    MEK Hussey           733
# 1088    2014    RV Uthappa           660
# 1148    2015     DA Warner           562
# 1383    2016       V Kohli           973
# 1422    2017     DA Warner           641
