# %% [markdown]
# <a href="https://colab.research.google.com/github/mradi004/data_science/blob/main/advance_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
marks=[67,45,78,98]
subjects=['maths','science','english','hindi']

# %%
marks_series=pd.Series(marks,index=subjects,name="nitish ke marks")

# %%
#size
marks_series.size
# Out:
# 4

# %%
#name
marks_series.name
# Out:
# 'nitish ke marks'

# %%
#index
marks_series.index
# Out:
# Index(['maths', 'science', 'english', 'hindi'], dtype='object')

# %%
marks_series.values
# Out:
# array([67, 45, 78, 98])

# %% [markdown]
# Series using read_csv

# %%
#with one col
df = pd.read_csv('/content/subs.csv')
subs_series = df.iloc[:, 0]

# %%
df
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs_series
# Out:
# dtype('int64')

# %%
#with 2 cols
vk=pd.read_csv('/content/kohli_ipl.csv',index_col='match_no')

# %%
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
movies=pd.read_csv('/content/bollywood.csv',index_col='movie')

# %%
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
df.head()
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
vk.tail()
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
#sample
movies.sample()
# Out:
#                     lead
# movie
# Dhoom  Abhishek Bachchan

# %%
#vaslue count
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Naveen Bawa          1
# Naushaad Abbas       1
# Nauheed Cyrusi       1
# Natalia Janoszek     1
# Nishikant Kamat      1
# Name: count, Length: 566, dtype: int64

# %%
#sort values
vk.sort_values(by='runs').head(2).values[0]
# Out:
# array([0])

# %%
vk.sort_values(by='runs')
# Out:
#           runs
# match_no
# 8            0
# 87           0
# 93           0
# 91           0
# 206          0
# ...        ...
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113
#
# [215 rows x 1 columns]

# %%
vk=pd.read_csv('//content/kohli_ipl.csv',index_col='match_no')

# %%
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %% [markdown]
# #mathematical methods

# %%
vk.count()
# Out:
# runs    215
# dtype: int64

# %%
df.sum()
# Out:
# Subscribers gained    49510
# dtype: int64

# %%
vk.max()
# Out:
# runs    113
# dtype: int64

# %%
vk.min()
# Out:
# runs    0
# dtype: int64

# %%
vk.describe()
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %%
#series indexing

# %%
x=pd.Series([12,13,14,15,16,17,18,19])

# %%
x[[0]]
# Out:
# 0    12
# dtype: int64

# %%
x[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-63-1103187032.py in <cell line: 0>()
# ----> 1 x[-1]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# ...

# %%
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
vk.iloc[1:5,0]
# Out:
# match_no
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
#slicing
vk[5:16]
# Out:
#           runs
# match_no
# 6            9
# 7           34
# 8            0
# 9           21
# 10           3
# 11          10
# 12          38
# 13           3
# 14          11
# 15          50
# 16           2

# %%
vk[-5:]
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
movies.iloc[[1,2,3,4]]
# Out:
#                                                   lead
# movie
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar

# %%
#editing series

# %%
marks_series[1]=100
# Out:
# /tmp/ipython-input-99-676866948.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1]=100

# %%
marks_series
# Out:
# maths       67
# science    100
# english     78
# hindi       98
# Name: nitish ke marks, dtype: int64

# %%
marks_series['data science']=89

# %%
marks_series
# Out:
# maths            67
# science         100
# english          78
# hindi            98
# data science     89
# Name: nitish ke marks, dtype: int64

# %%
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
movies['Why Cheat India']='alia bhatt'

# %%
movies
# Out:
#                                                   lead  \
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
#                                      The Accidental Prime Minister (film)  \
# movie
# Uri: The Surgical Strike                                       alia bhatt
# Battalion 609                                                  alia bhatt
# ...

# %%
movies.drop('Why Cheat India')
# Out:
#                                                       lead  \
# movie
# Uri: The Surgical Strike                     Vicky Kaushal
# Battalion 609                                  Vicky Ahuja
# The Accidental Prime Minister (film)           Anupam Kher
# Evening Shadows                           Mona Ambegaonkar
# Soni (film)                           Geetika Vidya Ohlyan
# ...                                                    ...
# Hum Tumhare Hain Sanam                      Shah Rukh Khan
# Aankhen (2002 film)                       Amitabh Bachchan
# Saathiya (film)                               Vivek Oberoi
# Company (film)                                  Ajay Devgn
# Awara Paagal Deewana                          Akshay Kumar
#
#                                      The Accidental Prime Minister (film)  \
# movie
# Uri: The Surgical Strike                                       alia bhatt
# Battalion 609                                                  alia bhatt
# ...

# %%
movies=movies.drop('Why Cheat India',axis=1)

# %%
movies
# Out:
#                                                       lead  \
# movie
# Uri: The Surgical Strike                     Vicky Kaushal
# Battalion 609                                  Vicky Ahuja
# The Accidental Prime Minister (film)           Anupam Kher
# Evening Shadows                           Mona Ambegaonkar
# Soni (film)                           Geetika Vidya Ohlyan
# ...                                                    ...
# Hum Tumhare Hain Sanam                      Shah Rukh Khan
# Aankhen (2002 film)                       Amitabh Bachchan
# Saathiya (film)                               Vivek Oberoi
# Company (film)                                  Ajay Devgn
# Awara Paagal Deewana                          Akshay Kumar
#
#                                      The Accidental Prime Minister (film)
# movie
# Uri: The Surgical Strike                                       alia bhatt
# Battalion 609                                                  alia bhatt
# ...

# %%
movies=movies.drop('The Accidental Prime Minister (film)',axis=1)

# %%
movies
# Out:
#                                                       lead
# movie
# Uri: The Surgical Strike                     Vicky Kaushal
# Battalion 609                                  Vicky Ahuja
# The Accidental Prime Minister (film)           Anupam Kher
# Evening Shadows                           Mona Ambegaonkar
# Soni (film)                           Geetika Vidya Ohlyan
# ...                                                    ...
# Hum Tumhare Hain Sanam                      Shah Rukh Khan
# Aankhen (2002 film)                       Amitabh Bachchan
# Saathiya (film)                               Vivek Oberoi
# Company (film)                                  Ajay Devgn
# Awara Paagal Deewana                          Akshay Kumar
#
# [1499 rows x 1 columns]

# %%
#series with python functionality

# %%
print(len(movies))
# Out:
# 1499

# %%
dir(movies)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
dict[marks_series]
# Out:
# dict[maths            67
# science         100
# english          78
# hindi            98
# data science     89
# Name: nitish ke marks, dtype: int64]

# %%
'Why Cheat India' in movies
# Out:
# False

# %%
for i in movies.index:
  print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# Dream Girl (2019 film)
# ...

# %%
#arithmetic operators(broadcasting)

# %%
100-marks_series
# Out:
# maths           33
# science          0
# english         22
# hindi            2
# data science    11
# Name: nitish ke marks, dtype: int64

# %%
vk>=50
# Out:
#            runs
# match_no
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# ...         ...
# 211       False
# 212       False
# 213        True
# 214       False
# 215       False
#
# [215 rows x 1 columns]

# %%
#boolean indexing

# %%
vk[vk['runs']>=50]
# Out:
#           runs
# match_no
# 15          50
# 34          58
# 41          71
# 44          56
# 45          67
# 52          70
# 57          57
# 68          73
# 71          51
# 73          58
# 74          65
# 80          57
# 81          93
# 82          99
# 85          56
# 97          67
# 99          73
# 103         51
# 104         62
# 110         82
# 116         75
# 117         79
# 119         80
# 120        100
# 122         52
# 123        108
# 126        109
# 127         75
# 128        113
# 129         54
# 131         54
# 132         62
# 134         64
# 137         55
# 141         58
# 144         57
# 145         92
# 148         68
# 152         70
# 160         84
# 162         67
# 164        100
# 175         72
# 178         90
# 182         50
# 188         72
# 197         51
# 198         53
# 209         58
# 213         73

# %%
vk[vk.values==0]
# Out:
#           runs
# match_no
# 8            0
# 87           0
# 91           0
# 93           0
# 130          0
# 135          0
# 206          0
# 207          0
# 211          0

# %%
num_movies=movies.value_counts()
num_movies[num_movies>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Name: count, dtype: int64

# %%
#graphs

# %%
df.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
#supplementary

# %%
#astype
vk.astype('int16')
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
vk=vk['runs'].astype('float')

# %%
vk
# Out:
# match_no
# 1       1.0
# 2      23.0
# 3      13.0
# 4      12.0
# 5       1.0
#        ...
# 211     0.0
# 212    20.0
# 213    73.0
# 214    25.0
# 215     7.0
# Name: runs, Length: 215, dtype: float64

# %%
#between
vk[vk.between(51,99)]
# Out:
# match_no
# 34     58.0
# 41     71.0
# 44     56.0
# 45     67.0
# 52     70.0
# 57     57.0
# 68     73.0
# 71     51.0
# 73     58.0
# 74     65.0
# 80     57.0
# 81     93.0
# 82     99.0
# 85     56.0
# 97     67.0
# 99     73.0
# 103    51.0
# 104    62.0
# 110    82.0
# 116    75.0
# 117    79.0
# 119    80.0
# 122    52.0
# 127    75.0
# 129    54.0
# 131    54.0
# 132    62.0
# 134    64.0
# 137    55.0
# 141    58.0
# 144    57.0
# 145    92.0
# 148    68.0
# 152    70.0
# 160    84.0
# 162    67.0
# 175    72.0
# 178    90.0
# 188    72.0
# 197    51.0
# 198    53.0
# 209    58.0
# 213    73.0
# Name: runs, dtype: float64

# %%
df.clip(100,200)
# Out:
#      Subscribers gained
# 0                   100
# 1                   100
# 2                   100
# 3                   100
# 4                   100
# ..                  ...
# 360                 200
# 361                 200
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
temp=pd.Series([1,1,1,2,2,3,4,5,7,7,8])

# %%
temp.drop_duplicates(keep='last')
# Out:
# 2     1
# 4     2
# 5     3
# 6     4
# 7     5
# 9     7
# 10    8
# dtype: int64

# %%
movies.drop_duplicates()
# Out:
#                                                       lead
# movie
# Uri: The Surgical Strike                     Vicky Kaushal
# Battalion 609                                  Vicky Ahuja
# The Accidental Prime Minister (film)           Anupam Kher
# Evening Shadows                           Mona Ambegaonkar
# Soni (film)                           Geetika Vidya Ohlyan
# ...                                                    ...
# Sssshhh...                                Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                    Tanuja
# Right Here Right Now (film)                          Ankit
# Talaash: The Hunt Begins...                  Rakhee Gulzar
# The Pink Mirror                            Edwin Fernandes
#
# [566 rows x 1 columns]

# %%
temp.duplicated().sum()
# Out:
# np.int64(4)

# %%
#handling missing values
temp=pd.Series([1,2,3,4,np.nan,9,6,np.nan] )

# %%
temp.isnull().sum()
# Out:
# np.int64(2)

# %%
#dropna
temp.dropna()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 5    9.0
# 6    6.0
# dtype: float64

# %%
temp.fillna(0)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    0.0
# 5    9.0
# 6    6.0
# 7    0.0
# dtype: float64

# %%
#isin
vk[(vk==49)|(vk==99)]
# Out:
# match_no
# 82    99.0
# 86    49.0
# Name: runs, dtype: float64

# %%
vk[vk.isin([49,99])]
# Out:
# match_no
# 82    99.0
# 86    49.0
# Name: runs, dtype: float64

# %%
movies['lead'].apply(lambda x:x.split())
# Out:
# movie
# Uri: The Surgical Strike                        [Vicky, Kaushal]
# Battalion 609                                     [Vicky, Ahuja]
# The Accidental Prime Minister (film)              [Anupam, Kher]
# Evening Shadows                              [Mona, Ambegaonkar]
# Soni (film)                             [Geetika, Vidya, Ohlyan]
#                                                   ...
# Hum Tumhare Hain Sanam                        [Shah, Rukh, Khan]
# Aankhen (2002 film)                          [Amitabh, Bachchan]
# Saathiya (film)                                  [Vivek, Oberoi]
# Company (film)                                     [Ajay, Devgn]
# Awara Paagal Deewana                             [Akshay, Kumar]
# Name: lead, Length: 1499, dtype: object

# %%
meanof=df['Subscribers gained'].mean()

# %%
df['new data']=df['Subscribers gained'].apply(lambda x:'good day' if x > meanof else 'bad day')

# %%
df
# Out:
#      Subscribers gained  new data
# 0                    48   bad day
# 1                    57   bad day
# 2                    40   bad day
# 3                    43   bad day
# 4                    44   bad day
# ..                  ...       ...
# 360                 231  good day
# 361                 226  good day
# 362                 155  good day
# 363                 144  good day
# 364                 172  good day
#
# [365 rows x 2 columns]

# %%
#copy and view

# %%
new=vk.head()

# %%
new[1]
# Out:
# np.float64(1.0)

# %%
new[1]=1

# %%
new2=vk.head().copy()

# %%
new2[1]=23

# %%
new2
# Out:
# match_no
# 1    23.0
# 2    23.0
# 3    13.0
# 4    12.0
# 5     1.0
# Name: runs, dtype: float64
