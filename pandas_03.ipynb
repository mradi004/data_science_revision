# %% [markdown]
# <a href="https://colab.research.google.com/github/mradi004/data_science/blob/main/pandas_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# fifth lecture video codes
#
# ```

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1={
    'a':[1,2,3,4,5],
    'b':[6,7,8,9,10],
    'c':[11,12,13,14,15]
}

# %%
dt1=pd.DataFrame(data1)

# %%
dt1
# Out:
#    a   b   c
# 0  1   6  11
# 1  2   7  12
# 2  3   8  13
# 3  4   9  14
# 4  5  10  15

# %%
dt1.set_index('a',inplace=True)

# %%
dt1
# Out:
#     b   c
# a
# 1   6  11
# 2   7  12
# 3   8  13
# 4   9  14
# 5  10  15

# %%
dt1.reset_index(inplace=True)

# %%
data={
    'a':[1,2,3,4,5],
    'b':[6,7,8,9,10],
    'c':["Adi","shiva",'bhutki','sumit','chuhiya']
}
df2=pd.DataFrame(data,index=['a','b','c','d','e'])

# %%
df2
# Out:
#    a   b        c
# a  1   6      Adi
# b  2   7    shiva
# c  3   8   bhutki
# d  4   9    sumit
# e  5  10  chuhiya

# %%
df2=df2.reindex(['b','c','e','a','d'])

# %%
df2
# Out:
#    a   b        c
# b  2   7    shiva
# c  3   8   bhutki
# e  5  10  chuhiya
# a  1   6      Adi
# d  4   9    sumit

# %%
for i in df2.iterrows():
  print(i)
# Out:
# ('b', a        2
# b        7
# c    shiva
# Name: b, dtype: object)
# ('c', a         3
# b         8
# c    bhutki
# Name: c, dtype: object)
# ('e', a          5
# b         10
# c    chuhiya
# Name: e, dtype: object)
# ('a', a      1
# b      6
# c    Adi
# Name: a, dtype: object)
# ('d', a        4
# b        9
# c    sumit
# Name: d, dtype: object)

# %%
for index,row in df2.iterrows():
  # print(index)
  print(row)
# Out:
# a        2
# b        7
# c    shiva
# Name: b, dtype: object
# a         3
# b         8
# c    bhutki
# Name: c, dtype: object
# a          5
# b         10
# c    chuhiya
# Name: e, dtype: object
# a      1
# b      6
# c    Adi
# Name: a, dtype: object
# a        4
# b        9
# c    sumit
# Name: d, dtype: object

# %%
for i in df2.items():
  print(i)
# Out:
# ('a', b    2
# c    3
# e    5
# a    1
# d    4
# Name: a, dtype: int64)
# ('b', b     7
# c     8
# e    10
# a     6
# d     9
# Name: b, dtype: int64)
# ('c', b      shiva
# c     bhutki
# e    chuhiya
# a        Adi
# d      sumit
# Name: c, dtype: object)

# %%
df2['a']
# Out:
# b    2
# c    3
# e    5
# a    1
# d    4
# Name: a, dtype: int64

# %%
[i for i in df2['a']]
# Out:
# [2, 3, 5, 1, 4]

# %%
def test(x):
  return x.sum()

df2.apply(test)
# Out:
# a                            15
# b                            40
# c    shivabhutkichuhiyaAdisumit
# dtype: object

# %%
df2.applymap(lambda x:x*2)
# Out:
# /tmp/ipython-input-32-3904330708.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2.applymap(lambda x:x*2)
#     a   b               c
# b   4  14      shivashiva
# c   6  16    bhutkibhutki
# e  10  20  chuhiyachuhiya
# a   2  12          AdiAdi
# d   8  18      sumitsumit

# %%
df2.sort_values('c')
# Out:
#    a   b        c
# a  1   6      Adi
# c  3   8   bhutki
# e  5  10  chuhiya
# b  2   7    shiva
# d  4   9    sumit

# %%
df2.sort_index()
# Out:
#    a   b        c
# a  1   6      Adi
# b  2   7    shiva
# c  3   8   bhutki
# d  4   9    sumit
# e  5  10  chuhiya

# %%
df2
# Out:
#    a   b        c
# b  2   7    shiva
# c  3   8   bhutki
# e  5  10  chuhiya
# a  1   6      Adi
# d  4   9    sumit

# %%
df2['a'][0]
# Out:
# /tmp/ipython-input-38-3509210578.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df2['a'][0]
# np.int64(2)

# %%
df2
# Out:
#    a   b        c
# b  2   7    shiva
# c  3   8   bhutki
# e  5  10  chuhiya
# a  1   6      Adi
# d  4   9    sumit

# %% [markdown]
# #statistics functions

# %%
df2['a'].mean()
# Out:
# np.float64(3.0)

# %%
df2['a'].median()
# Out:
# 3.0

# %%
df2['a'].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: a, dtype: int64

# %%
df2['a'].std()
# Out:
# 1.5811388300841898

# %%
df4=pd.DataFrame({'a':[2,4,5,3,6,7,8,9]})

# %%
df4['a'].rolling(window=1).mean()
# Out:
# 0    2.0
# 1    4.0
# 2    5.0
# 3    3.0
# 4    6.0
# 5    7.0
# 6    8.0
# 7    9.0
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=2).mean()
# Out:
# 0    NaN
# 1    3.0
# 2    4.5
# 3    4.0
# 4    4.5
# 5    6.5
# 6    7.5
# 7    8.5
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=3).mean()
# Out:
# 0         NaN
# 1         NaN
# 2    3.666667
# 3    4.000000
# 4    4.666667
# 5    5.333333
# 6    7.000000
# 7    8.000000
# Name: a, dtype: float64

# %%
df4['a'].cumsum()
# Out:
# 0     2
# 1     6
# 2    11
# 3    14
# 4    20
# 5    27
# 6    35
# 7    44
# Name: a, dtype: int64

# %%
df4
# Out:
#    a
# 0  2
# 1  4
# 2  5
# 3  3
# 4  6
# 5  7
# 6  8
# 7  9

# %%
#date functionality in python pandas

# %%
date=pd.date_range(start='2023-04-23',end='2023-06-23')

# %%
date
# Out:
# DatetimeIndex(['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
#                '2023-04-27', '2023-04-28', '2023-04-29', '2023-04-30',
#                '2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07', '2023-05-08',
#                '2023-05-09', '2023-05-10', '2023-05-11', '2023-05-12',
#                '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16',
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20',
#                '2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24',
#                '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28',
#                '2023-05-29', '2023-05-30', '2023-05-31', '2023-06-01',
#                '2023-06-02', '2023-06-03', '2023-06-04', '2023-06-05',
#                '2023-06-06', '2023-06-07', '2023-06-08', '2023-06-09',
#                '2023-06-10', '2023-06-11', '2023-06-12', '2023-06-13',
# ...

# %%
df_date=pd.DataFrame({'date':date})

# %%
df_date
# Out:
#          date
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27
# ..        ...
# 57 2023-06-19
# 58 2023-06-20
# 59 2023-06-21
# 60 2023-06-22
# 61 2023-06-23
#
# [62 rows x 1 columns]

# %%
df_date2=pd.DataFrame({'date':['2023-06-19','2023-06-20','2023-06-22']})

# %%
df_date2
# Out:
#          date
# 0  2023-06-19
# 1  2023-06-20
# 2  2023-06-22

# %%
df_date2['updated_date']=pd.to_datetime(df_date2['date'])

# %%
df_date2.dtypes
# Out:
# date                    object
# updated_date    datetime64[ns]
# dtype: object

# %%
df_date2['only_month']=df_date2['updated_date'].dt.month

# %%
df_date2
# Out:
#          date updated_date  only_month
# 0  2023-06-19   2023-06-19           6
# 1  2023-06-20   2023-06-20           6
# 2  2023-06-22   2023-06-22           6

# %%
df_date2['only_year']=df_date2['updated_date'].dt.year

# %%
df_date2['only day']=df_date2['updated_date'].dt.day

# %%
df_date2
# Out:
#          date updated_date  only_month  only_year  only day
# 0  2023-06-19   2023-06-19           6       2023        19
# 1  2023-06-20   2023-06-20           6       2023        20
# 2  2023-06-22   2023-06-22           6       2023        22

# %%
#timedelta

# %%
pd.Timedelta(days=10,hours=5,minutes=20,seconds=20)
# Out:
# Timedelta('10 days 05:20:20')

# %%
a=pd.to_datetime('2023-09-5')

# %%
pd.Timedelta(days=1)+a
# Out:
# Timestamp('2023-09-06 00:00:00')

# %%
#categorical data

# %%
data=['suhd','krish','naveen','aditya']

# %%
pd.Categorical(data)
# Out:
# ['suhd', 'krish', 'naveen', 'aditya']
# Categories (4, object): ['aditya', 'krish', 'naveen', 'suhd']

# %%
cat=pd.Categorical(data)

# %%
cat.value_counts()
# Out:
# aditya    1
# krish     1
# naveen    1
# suhd      1
# Name: count, dtype: int64

# %%
#data visualization

# %%
D=pd.Series([1,2,3,9,5,6,7,8])

# %%
D.plot(kind='bar')
# Out:
# <Axes: >

# %%
df9=pd.DataFrame({'a':[1,2,3,4,5],'b':[6,7,8,9,10]})

# %%
df9.plot.scatter(x='a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>
