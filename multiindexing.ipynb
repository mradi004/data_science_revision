# %% [markdown]
# <a href="https://colab.research.google.com/github/mradi004/data_science/blob/main/multiindexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
index_val=[('cse',2019),('cse',2020),('cse',2021),('cse',2022),('ece',2019),('ece',2020),('ece',2021),('ece',2022)]

# %%
a=pd.Series([1,2,3,4,5,6,7,8],index=index_val)

# %%
multindex=pd.MultiIndex.from_tuples(index_val)

# %%
multindex.levels[0]
# Out:
# Index(['cse', 'ece'], dtype='object')

# %%
#multiindex from product
multiindexproduct=pd.MultiIndex.from_product([['cse','ece'],[2010,2011,2012,2013,2014]])

# %%
s=pd.Series([1,2,3,4,5,6,7,8],index=multindex)

# %%
s[('cse',2020)]
# Out:
# np.int64(2)

# %%
temp=s.unstack()

# %%
temp.stack()
# Out:
# cse  2019    1
#      2020    2
#      2021    3
#      2022    4
# ece  2019    5
#      2020    6
#      2021    7
#      2022    8
# dtype: int64

# %%
branch_df=pd.DataFrame([
    [1,2],
    [2,3],
    [4,5],
    [6,7],
    [7,8],
    [8,9],
    [3,4],
    [5,9]
],index=multindex,columns=[['avg','students']]
)

# %%
branch_df
# Out:
#          avg students
# cse 2019   1        2
#     2020   2        3
#     2021   4        5
#     2022   6        7
# ece 2019   7        8
#     2020   8        9
#     2021   3        4
#     2022   5        9

# %%
branch_df.loc[['cse','ece'],'avg']
# Out:
#          avg
# cse 2019   1
#     2020   2
#     2021   4
#     2022   6
# ece 2019   7
#     2020   8
#     2021   3
#     2022   5

# %%
branch_df['avg']
# Out:
#          avg
# cse 2019   1
#     2020   2
#     2021   4
#     2022   6
# ece 2019   7
#     2020   8
#     2021   3
#     2022   5

# %%
#multindex df from columns perspective
branch_df=pd.DataFrame(
    [
    [1,2,3,4],
    [4,5,6,7],
    [5,7,8,9],
    [3,5,7,9]
], index=[2010,2011,2012,2013],columns=pd.MultiIndex.from_product([['delhi','mumbai'],['avg','students']]))

# %%
branch_df
# Out:
#      delhi          mumbai
#        avg students    avg students
# 2010     1        2      3        4
# 2011     4        5      6        7
# 2012     5        7      8        9
# 2013     3        5      7        9

# %%
branch_df.T
# Out:
#                  2010  2011  2012  2013
# delhi  avg          1     4     5     3
#        students     2     5     7     5
# mumbai avg          3     6     8     7
#        students     4     7     9     9

# %%
#multindex df in terms of both cols and index
branch_df3=pd.DataFrame(
    [
        [1,2,3,4],
        [4,5,6,7],
        [5,7,8,9],
        [3,5,7,9],
        [4,5,6,7],
        [5,7,8,9],
        [3,5,7,9],
        [4,5,6,7]

    ],index=multindex,columns=pd.MultiIndex.from_product([['delhi','mumbai'],['avg','students']])
)

# %%
branch_df3
# Out:
#          delhi          mumbai
#            avg students    avg students
# cse 2019     1        2      3        4
#     2020     4        5      6        7
#     2021     5        7      8        9
#     2022     3        5      7        9
# ece 2019     4        5      6        7
#     2020     5        7      8        9
#     2021     3        5      7        9
#     2022     4        5      6        7

# %% [markdown]
# #stacking and unstacking

# %%
branch_df
# Out:
#      delhi          mumbai
#        avg students    avg students
# 2010     1        2      3        4
# 2011     4        5      6        7
# 2012     5        7      8        9
# 2013     3        5      7        9

# %%
branch_df.stack().stack().unstack().unstack().unstack()
# Out:
# /tmp/ipython-input-61-2392609.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   branch_df.stack().stack().unstack().unstack().unstack()
# delhi   avg       2010    1
#                   2011    4
#                   2012    5
#                   2013    3
#         students  2010    2
#                   2011    5
#                   2012    7
#                   2013    5
# mumbai  avg       2010    3
#                   2011    6
#                   2012    8
#                   2013    7
#         students  2010    4
#                   2011    7
#                   2012    9
#                   2013    9
# dtype: int64

# %%
branch_df.unstack()
# Out:
# delhi   avg       2010    1
#                   2011    4
#                   2012    5
#                   2013    3
#         students  2010    2
#                   2011    5
#                   2012    7
#                   2013    5
# mumbai  avg       2010    3
#                   2011    6
#                   2012    8
#                   2013    7
#         students  2010    4
#                   2011    7
#                   2012    9
#                   2013    9
# dtype: int64

# %%
branch_df3
# Out:
#          delhi          mumbai
#            avg students    avg students
# cse 2019     1        2      3        4
#     2020     4        5      6        7
#     2021     5        7      8        9
#     2022     3        5      7        9
# ece 2019     4        5      6        7
#     2020     5        7      8        9
#     2021     3        5      7        9
#     2022     4        5      6        7

# %%
#head
#tail
branch_df3
#info
#shape
branch_df3.duplicated()
# Out:
# cse  2019    False
#      2020    False
#      2021    False
#      2022    False
# ece  2019     True
#      2020     True
#      2021     True
#      2022     True
# dtype: bool

# %%
branch_df3.loc[('cse',2019)]
# Out:
# delhi   avg         1
#         students    2
# mumbai  avg         3
#         students    4
# Name: (cse, 2019), dtype: int64

# %%
branch_df3.loc[('cse',2019):('cse',2022):2]
# Out:
#          delhi          mumbai
#            avg students    avg students
# cse 2019     1        2      3        4
#     2021     5        7      8        9

# %%
#extarcting the columns
branch_df3['delhi']
# Out:
#           avg  students
# cse 2019    1         2
#     2020    4         5
#     2021    5         7
#     2022    3         5
# ece 2019    4         5
#     2020    5         7
#     2021    3         5
#     2022    4         5

# %%
#sorting
branch_df3.sort_index(ascending=False)
branch_df3.sort_index(ascending=[False,True])
# Out:
#          delhi          mumbai
#            avg students    avg students
# ece 2019     4        5      6        7
#     2020     5        7      8        9
#     2021     3        5      7        9
#     2022     4        5      6        7
# cse 2019     1        2      3        4
#     2020     4        5      6        7
#     2021     5        7      8        9
#     2022     3        5      7        9

# %%
#swapping the levels
branch_df3.swaplevel()
# Out:
#          delhi          mumbai
#            avg students    avg students
# 2019 cse     1        2      3        4
# 2020 cse     4        5      6        7
# 2021 cse     5        7      8        9
# 2022 cse     3        5      7        9
# 2019 ece     4        5      6        7
# 2020 ece     5        7      8        9
# 2021 ece     3        5      7        9
# 2022 ece     4        5      6        7

# %%
branch_df3.swaplevel(axis=1)
# Out:
#            avg students    avg students
#          delhi    delhi mumbai   mumbai
# cse 2019     1        2      3        4
#     2020     4        5      6        7
#     2021     5        7      8        9
#     2022     3        5      7        9
# ece 2019     4        5      6        7
#     2020     5        7      8        9
#     2021     3        5      7        9
#     2022     4        5      6        7

# %%
#long vs wide data

# %%
#melt=wide data format ko long me convert krta hai
#pivot->long to wide

# %%
pd.DataFrame({'cse':[120]}).melt()
# Out:
#   variable  value
# 0      cse    120

# %%
pd.DataFrame({'cse':[120],'ece':[130],'it':[130]}).melt(var_name='branch',value_name='students')
# Out:
#   branch  students
# 0    cse       120
# 1    ece       130
# 2     it       130

# %%
pd.DataFrame(
    {
        'branch':['cse','ece','it'],
        '2020':[120,130,140],
        '2021':[130,140,150]
    }
).melt(id_vars=['branch'])
# Out:
#   branch variable  value
# 0    cse     2020    120
# 1    ece     2020    130
# 2     it     2020    140
# 3    cse     2021    130
# 4    ece     2021    140
# 5     it     2021    150

# %%
death=pd.read_csv('/content/time_series_covid19_deaths_global.csv')
confirmed=pd.read_csv('/content/time_series_covid19_confirmed_global.csv')

# %%
confirmed.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  12/24/22  12/25/22  12/26/22  \
# 0        0        0        0        0  ...    207310    207399    207438
# 1        0        0        0        0  ...    333749    333749    333751
# 2        0        0        0        0  ...    271194    271198    271198
# 3        0        0        0        0  ...     47686     47686     47686
# 4        0        0        0        0  ...    104973    104973    104973
#
#    12/27/22  12/28/22  12/29/22  12/30/22  12/31/22  1/1/23  1/2/23
# ...

# %%
death=death.melt(id_vars=['Province/State','Country/Region','Lat','Long'],var_name='dates',value_name='death')
confirm=confirmed.melt(id_vars=['Province/State','Country/Region','Lat','Long'],var_name='dates',value_name='cases')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-106-1696736517.py in <cell line: 0>()
# ----> 1 death=death.melt(id_vars=['Province/State','Country/Region','Lat','Long'],var_name='dates',value_name='death')
#       2 confirm=confirmed.melt(id_vars=['Province/State','Country/Region','Lat','Long'],var_name='dates',value_name='cases')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    9940         ignore_index: bool = True,
#    9941     ) -> DataFrame:
# -> 9942         return melt(
#    9943             self,
#    9944             id_vars=id_vars,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      52 ) -> DataFrame:
# ...

# %%
death
# Out:
#        Province/State        Country/Region        Lat        Long    dates  \
# 0                 NaN           Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN               Albania  41.153300   20.168300  1/22/20
# 2                 NaN               Algeria  28.033900    1.659600  1/22/20
# 3                 NaN               Andorra  42.506300    1.521800  1/22/20
# 4                 NaN                Angola -11.202700   17.873900  1/22/20
# ...               ...                   ...        ...         ...      ...
# 311248            NaN    West Bank and Gaza  31.952200   35.233200   1/2/23
# 311249            NaN  Winter Olympics 2022  39.904200  116.407400   1/2/23
# 311250            NaN                 Yemen  15.552727   48.516388   1/2/23
# 311251            NaN                Zambia -13.133897   27.849332   1/2/23
# 311252            NaN              Zimbabwe -19.015438   29.154857   1/2/23
#
#         death
# 0           0
# 1           0
# ...

# %%
confirm
# Out:
#        Province/State        Country/Region        Lat        Long    dates  \
# 0                 NaN           Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN               Albania  41.153300   20.168300  1/22/20
# 2                 NaN               Algeria  28.033900    1.659600  1/22/20
# 3                 NaN               Andorra  42.506300    1.521800  1/22/20
# 4                 NaN                Angola -11.202700   17.873900  1/22/20
# ...               ...                   ...        ...         ...      ...
# 311248            NaN    West Bank and Gaza  31.952200   35.233200   1/2/23
# 311249            NaN  Winter Olympics 2022  39.904200  116.407400   1/2/23
# 311250            NaN                 Yemen  15.552727   48.516388   1/2/23
# 311251            NaN                Zambia -13.133897   27.849332   1/2/23
# 311252            NaN              Zimbabwe -19.015438   29.154857   1/2/23
#
#          death
# 0            0
# 1            0
# ...

# %%
confirm.merge(death,on=['Province/State','Country/Region','Lat','Long','dates'])[['dates','Country/Region']]
# Out:
#           dates        Country/Region
# 0       1/22/20           Afghanistan
# 1       1/22/20               Albania
# 2       1/22/20               Algeria
# 3       1/22/20               Andorra
# 4       1/22/20                Angola
# ...         ...                   ...
# 311248   1/2/23    West Bank and Gaza
# 311249   1/2/23  Winter Olympics 2022
# 311250   1/2/23                 Yemen
# 311251   1/2/23                Zambia
# 311252   1/2/23              Zimbabwe
#
# [311253 rows x 2 columns]

# %%
#pivot table
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.groupby('sex')['total_bill'].mean()
# Out:
# /tmp/ipython-input-115-3953205823.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('sex')['total_bill'].mean()
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
df.groupby(['sex','smoker'])['total_bill'].mean().unstack()
# Out:
# /tmp/ipython-input-119-2279680371.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['sex','smoker'])['total_bill'].mean().unstack()
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185

# %%
df.pivot_table(index='sex',columns='smoker',values='total_bill',aggfunc='sum')
# Out:
# /tmp/ipython-input-121-3627826641.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index='sex',columns='smoker',values='total_bill',aggfunc='sum')
# smoker      Yes       No
# sex
# Male    1337.07  1919.75
# Female   593.27   977.68

# %%
#multidimensional
df.pivot_table(index=['sex','smoker'],columns=['day','time'],values='total_bill')
# Out:
# /tmp/ipython-input-123-2145788695.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index=['sex','smoker'],columns=['day','time'],values='total_bill')
# day                 Thur               Fri                Sat        Sun
# time               Lunch Dinner      Lunch  Dinner     Dinner     Dinner
# sex    smoker
# Male   Yes     19.171000    NaN  11.386667  25.892  21.837778  26.141333
#        No      18.486500    NaN        NaN  17.475  19.929063  20.403256
# Female Yes     19.218571    NaN  13.260000  12.200  20.266667  16.540000
#        No      15.899167  18.78  15.980000  22.750  19.003846  20.824286

# %%
expense=pd.read_csv('/content/expense_data.csv')

# %%
expense
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          NaN
# 1      3/2/2022 10:11  CUB - online payment           Other          NaN
# 2      3/1/2022 19:50  CUB - online payment            Food          NaN
# 3      3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4      3/1/2022 18:22  CUB - online payment            Food          NaN
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          NaN
# 273  11/22/2021 14:16  CUB - online payment            Food          NaN
# 274  11/21/2021 17:07  CUB - online payment  Transportation          NaN
# 275  11/21/2021 15:50  CUB - online payment            Food          NaN
# 276  11/21/2021 13:30  CUB - online payment           Other          NaN
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# ...

# %%
expense['Category'].value_counts()
# Out:
# Category
# Food                156
# Other                60
# Transportation       31
# Apparel               7
# Household             6
# Allowance             6
# Social Life           5
# Education             1
# Salary                1
# Self-development      1
# Beauty                1
# Gift                  1
# Petty cash            1
# Name: count, dtype: int64

# %%
expense['Date']=pd.to_datetime(expense['Date'])

# %%
expense.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[ns]
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 23.9+ KB

# %%
expense['month']=expense['Date'].dt.month_name()

# %%
expense.pivot_table(index='month',columns='Category',values='INR',aggfunc='sum',fill_value=0)
# Out:
# Category  Allowance  Apparel  Beauty  Education     Food   Gift  Household  \
# month
# December    11000.0   2590.0   196.0        0.0  6440.72    0.0     4800.0
# February        0.0    798.0     0.0        0.0  5579.85    0.0     2808.0
# January      1000.0      0.0     0.0     1400.0  9112.51    0.0     4580.0
# March           0.0      0.0     0.0        0.0   195.00    0.0        0.0
# November     2000.0      0.0     0.0        0.0  3174.40  115.0        0.0
#
# Category    Other  Petty cash  Salary  Self-development  Social Life  \
# month
# December   1790.0         0.0     0.0             400.0       513.72
# February  20000.0         0.0     0.0               0.0      1800.00
# January   13178.0         0.0  8000.0               0.0       200.00
# March       900.0         0.0     0.0               0.0         0.00
# November   2000.0         3.0     0.0               0.0         0.00
#
# Category  Transportation
# month
# December           914.0
# ...
