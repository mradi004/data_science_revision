# %% [markdown]
# <a href="https://colab.research.google.com/github/mradi004/data_science/blob/main/advancedmlt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
iris=pd.read_csv('/content/iris.csv')

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris['Species']=iris['Species'].replace({'Iris-setosa':0,'Iris-virginica':1,'Iris-versicolor':2})
# Out:
# /tmp/ipython-input-34-1173525650.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species']=iris['Species'].replace({'Iris-setosa':0,'Iris-virginica':1,'Iris-versicolor':2})

# %%
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 134  135            6.1           2.6            5.6           1.4        1
# 59    60            5.2           2.7            3.9           1.4        2
# 70    71            5.9           3.2            4.8           1.8        2
# 131  132            7.9           3.8            6.4           2.0        1
# 104  105            6.5           3.0            5.8           2.2        1

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],alpha=0.5)
plt.title('Scatter Plot')
plt.xlabel('SepalLengthCm')
plt.ylabel('PetalLengthCm')
plt.colorbar()
plt.show()

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],alpha=0.5)
plt.title('Scatter Plot')
plt.xlabel('SepalLengthCm')
plt.ylabel('PetalLengthCm')
plt.colorbar()
plt.figure(figsize=(0.5,1))
plt.show()

# %%
batter=pd.read_csv('/content/batter (1).csv')

# %%
batter.sample()
# Out:
#        batter  runs        avg  strike_rate
# 76  ML Hayden  1107  35.709677   131.942789

# %%
sample_df=batter.head(100).sample(25,random_state=5)

# %%
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.scatter(sample_df['avg'],sample_df['strike_rate'])

# %%
#indicating the points like
a=[1,2,3,4,5]
b=[5,6,7,8,9]
plt.scatter(a,b)
plt.text(1,5,'point 1',fontdict={'size':15,'color':'red'})
plt.show()

# %%
plt.scatter(sample_df['avg'],sample_df['strike_rate'])
plt.axhline(130)
for i in range(sample_df.shape[0]):
  plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %%
#subplots

# %%
batter.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
fig,ax=plt.subplots(figsize=(15,6))
ax.scatter(batter['avg'],batter['strike_rate'])
ax.set_title('scatter plot')
ax.set_xlabel('avg')
ax.set_ylabel('strike_rate')
# Out:
# Text(0, 0.5, 'strike_rate')

# %%
fig,ax=plt.subplots(nrows=2,ncols=1)
ax[0].scatter(sample_df['avg'],sample_df['strike_rate'])
ax[1].scatter(sample_df['avg'],sample_df['runs'])
plt.tight_layout()

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,8))
ax[0,0].scatter(sample_df['avg'],sample_df['strike_rate'])
ax[1,0].scatter(sample_df['avg'],sample_df['runs'])
ax[0,1].scatter(batter['avg'],batter['strike_rate'])
ax[1,1].scatter(batter['avg'],batter['runs'])
plt.tight_layout()

# %%
fig=plt.figure()

# %% [markdown]
# #3d plotting

# %%
#3d scatter plot
fig=plt.figure()
ax=plt.subplot(projection='3d')
ax.scatter3D(batter['avg'],batter['strike_rate'],batter['runs'])

# %%
#LINE PLOT
x=[0,1,5]
y=[0,10,13]
z=[0,13,20]

fig=plt.figure()
ax=plt.subplot(projection='3d')
ax.scatter3D(x,y,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.plot3D(x,y,z)

# %%
#3D SURFACE PLOT
x=np.linspace(-10,10,100)
y=np.linspace(-10,10,100)
xx,yy=np.meshgrid(x,y)
Z=xx**2+yy**2
fig=plt.figure()

ax=plt.subplot(projection='3d')
ax.plot_surface(xx,yy,z,cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-54-2715013867.py in <cell line: 0>()
#       7
#       8 ax=plt.subplot(projection='3d')
# ----> 9 ax.plot_surface(xx,yy,z,cmap='viridis')
#
# /usr/local/lib/python3.11/dist-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, axlim_clip, **kwargs)
#    2200         had_data = self.has_data()
#    2201
# -> 2202         if Z.ndim != 2:
#    2203             raise ValueError("Argument Z must be 2-dimensional.")
#    2204
#
# AttributeError: 'list' object has no attribute 'ndim'

# %%
z=np.sign(xx)+np.cos(yy)
ax=plt.subplot(projection='3d')
ax.plot_surface(xx,yy,z,cmap='viridis')

# %%
#contour plot
fig=plt.figure()
ax=plt.subplot()
p=ax.contourf(xx,yy,z,50)
fig.colorbar(p)

# %%
delivery=pd.read_csv('/content/IPL_Ball_by_Ball_2008_2022.csv')

# %%
delivery.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
temp=delivery[(delivery['ballnumber'].isin([1,2,3,4,5,6])) & (delivery['batsman_run']==6)]

# %%
grid=temp.pivot_table(index='overs',columns='ballnumber',values='batsman_run',aggfunc='count')

# %%
plt.figure(figsize=(20,10))
plt.imshow(grid)
plt.colorbar()

# %% [markdown]
# #pandas plotting

# %%
#on a series
batter['strike_rate'].plot()
# Out:
# <Axes: >

# %%
#can be used on a dataframe as well
tips=sns.load_dataset('tips')

# %%
tips.plot(x='total_bill',y='tip',kind='scatter')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips.plot(kind='bar',subplots=True,x='total_bill',y='tip')
# Out:
# array([<Axes: title={'center': 'tip'}, xlabel='total_bill'>], dtype=object)
